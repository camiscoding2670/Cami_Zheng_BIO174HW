# %%
import pandas as pd
import json

# Load the existing CSV dataset into a DataFrame
existing_data = pd.read_csv('tmdb_5000_movies.csv')

# Function to extract values after "name":
def extract_names(json_str):
    try:
        names = [item['name'] for item in json.loads(json_str)]
        return ", ".join(names)
    except (json.JSONDecodeError, TypeError):
        return ""
    
# Function to extract the year from release_date:
def extract_year(date_str):
    try:
        return date_str.split('-')[0]
    except AttributeError:
        return ""
    
# Extract genres, keywords, and release year in the specific way
existing_data['genres'] = existing_data['genres'].apply(extract_names)
existing_data['keywords'] = existing_data['keywords'].apply(extract_names)
existing_data['release_year'] = existing_data['release_date'].apply(extract_year)

# Selecting specific columns
selected_columns = ['budget', 'genres', 'homepage','keywords', 'original_language', 'overview', 
                    'popularity', 'release_year', 'title', 'vote_average']

# Create a new DataFrame with selected columns
new_dataframe = existing_data[selected_columns]

# Display the new DataFrame
print(new_dataframe)
new_dataframe.to_csv('new_dataset.csv', index=False)
# Out:
#          budget                                       genres  \
# 0     237000000  Action, Adventure, Fantasy, Science Fiction
# 1     300000000                   Adventure, Fantasy, Action
# 2     245000000                     Action, Adventure, Crime
# 3     250000000               Action, Crime, Drama, Thriller
# 4     260000000           Action, Adventure, Science Fiction
# ...         ...                                          ...
# 4798     220000                      Action, Crime, Thriller
# 4799       9000                              Comedy, Romance
# 4800          0             Comedy, Drama, Romance, TV Movie
# 4801          0
# 4802          0                                  Documentary
#
#                                                homepage  \
# 0                           http://www.avatarmovie.com/
# 1          http://disney.go.com/disneypictures/pirates/
# 2           http://www.sonypictures.com/movies/spectre/
# 3                    http://www.thedarkknightrises.com/
# 4                  http://movies.disney.com/john-carter
# ...                                                 ...
# 4798                                                NaN
# 4799                                                NaN
# 4800  http://www.hallmarkchannel.com/signedsealeddel...
# 4801                        http://shanghaicalling.com/
# 4802                                                NaN
#
#                                                keywords original_language  \
# 0     culture clash, future, space war, space colony...                en
# 1     ocean, drug abuse, exotic island, east india t...                en
# 2     spy, based on novel, secret agent, sequel, mi6...                en
# 3     dc comics, crime fighter, terrorist, secret id...                en
# 4     based on novel, mars, medallion, space travel,...                en
# ...                                                 ...               ...
# 4798  united states–mexico barrier, legs, arms, pape...                es
# 4799                                                                   en
# 4800  date, love at first sight, narration, investig...                en
# 4801                                                                   en
# 4802            obsession, camcorder, crush, dream girl                en
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#      release_year                                     title  vote_average
# 0            2009                                    Avatar           7.2
# 1            2007  Pirates of the Caribbean: At World's End           6.9
# 2            2015                                   Spectre           6.3
# 3            2012                     The Dark Knight Rises           7.6
# 4            2012                               John Carter           6.1
# ...           ...                                       ...           ...
# 4798         1992                               El Mariachi           6.6
# 4799         2011                                 Newlyweds           5.9
# 4800         2013                 Signed, Sealed, Delivered           7.0
# 4801         2012                          Shanghai Calling           5.7
# 4802         2005                         My Date with Drew           6.3
#
# [4803 rows x 10 columns]
